# %% [markdown]
# # High Ratings Clustering Analysis
# Analyzing clusters within highly-rated board games (rating >= 7.0).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Import clustering utilities
from cluster_utils import agglomerative_grid_search

# Set display options and styling
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 8)
plt.style.use('seaborn-v0_8-whitegrid')

# Create output directory for plots if it doesn't exist
import os
if not os.path.exists('../plots'):
    os.makedirs('../plots')
if not os.path.exists('../frames'):
    os.makedirs('../frames')

# %%
# Load processed data
filtered_df = pd.read_csv('../frames/filtered_games.csv')
all_binary_cols = np.load('../frames/all_binary_cols.npy', allow_pickle=True)
mechanics_cols = np.load('../frames/mechanics_cols.npy', allow_pickle=True)
themes_cols = np.load('../frames/themes_cols.npy', allow_pickle=True)
category_cols = np.load('../frames/category_cols.npy', allow_pickle=True)
subcategories_cols = np.load('../frames/subcategories_cols.npy', allow_pickle=True)

print(f"Loaded {len(filtered_df)} games with {len(all_binary_cols)} binary features")
# Out:
# Loaded 12239 games with 392 binary features

# %% [markdown]
# # Filter for High-Rated Games

# %%
# Define high rating threshold
HIGH_RATING_THRESHOLD = 7.0

# Filter for high-rated games
high_rated_games = filtered_df[filtered_df['AvgRating'] >= HIGH_RATING_THRESHOLD].copy()

print(f"Total games: {len(filtered_df)}")
print(f"High-rated games (>= {HIGH_RATING_THRESHOLD}): {len(high_rated_games)}")
print(f"Percentage of original dataset: {len(high_rated_games) / len(filtered_df) * 100:.1f}%")
print(f"Mean: {high_rated_games['AvgRating'].mean():.3f}")

# Visualize rating distribution of high-rated games
plt.figure(figsize=(10, 6))
sns.histplot(high_rated_games['AvgRating'], bins=20, kde=True)
plt.title(f'Rating Distribution of High-Rated Games (>= {HIGH_RATING_THRESHOLD})')
plt.xlabel('Average Rating')
plt.ylabel('Count')
plt.grid(axis='y', alpha=0.3)
plt.savefig('../plots/high_rating_distribution.png')
plt.show()
# Out:
# Total games: 12239
# High-rated games (>= 7.0): 3771
# Percentage of original dataset: 30.8%
# Mean: 7.512

# %% [markdown]
# # Cluster High-Rated Games

# %%
# Perform clustering on high-rated games
try:
    print("\nClustering high-rated games...")
    best_params, pca_result, labels, scores, pca, n_components = agglomerative_grid_search(
        high_rated_games, all_binary_cols, variance_threshold=0.8, max_components=50
    )
    
    # Add cluster labels to high_rated_games
    high_rated_games['HighRatingCluster'] = labels
    
    print(f"\nClustering completed with {len(set(labels))} clusters")
    print(f"Best parameters: n_clusters={best_params[0]}, linkage={best_params[1]}, metric={best_params[2]}")
    print(f"Silhouette score: {scores['silhouette']:.4f}")
    print(f"Calinski-Harabasz score: {scores['ch_score']:.1f}")
    print(f"Davies-Bouldin score: {scores['db_score']:.4f}")
    
except Exception as e:
    print(f"Error in clustering: {e}")
# Out:
# Clustering high-rated games...
# Using 50 PCA components (threshold would need 71)
# Variance explained with 50 components: 0.7182
#
# Grid search for Agglomerative Clustering parameters:
# n_clusters=5, linkage=ward, metric=euclidean: silhouette=0.0709, CH=221.8, DB=3.3678
# n_clusters=5, linkage=ward, metric=manhattan: Failed to calculate metrics
# n_clusters=5, linkage=ward, metric=cosine: Failed to calculate metrics
# n_clusters=5, linkage=complete, metric=euclidean: silhouette=0.0841, CH=68.3, DB=3.3297
# n_clusters=5, linkage=complete, metric=manhattan: silhouette=0.1095, CH=43.6, DB=3.6668
# n_clusters=5, linkage=complete, metric=cosine: silhouette=0.0124, CH=105.9, DB=4.4409
# n_clusters=5, linkage=average, metric=euclidean: silhouette=0.2004, CH=4.4, DB=1.0872
# n_clusters=5, linkage=average, metric=manhattan: silhouette=0.1969, CH=4.2, DB=1.2164
# n_clusters=5, linkage=average, metric=cosine: silhouette=0.0541, CH=222.5, DB=3.0067
# n_clusters=6, linkage=ward, metric=euclidean: silhouette=0.0729, CH=195.4, DB=3.1739
# n_clusters=6, linkage=ward, metric=manhattan: Failed to calculate metrics
# n_clusters=6, linkage=ward, metric=cosine: Failed to calculate metrics
# n_clusters=6, linkage=complete, metric=euclidean: silhouette=0.0408, CH=87.9, DB=3.4674
# n_clusters=6, linkage=complete, metric=manhattan: silhouette=0.1066, CH=35.9, DB=3.3175
# n_clusters=6, linkage=complete, metric=cosine: silhouette=0.0165, CH=101.8, DB=4.2377
# n_clusters=6, linkage=average, metric=euclidean: silhouette=0.1856, CH=4.3, DB=1.1913
# n_clusters=6, linkage=average, metric=manhattan: silhouette=0.1888, CH=5.0, DB=1.3472
# n_clusters=6, linkage=average, metric=cosine: silhouette=0.0546, CH=182.6, DB=3.0994
# n_clusters=7, linkage=ward, metric=euclidean: silhouette=0.0735, CH=177.3, DB=3.0773
# n_clusters=7, linkage=ward, metric=manhattan: Failed to calculate metrics
# n_clusters=7, linkage=ward, metric=cosine: Failed to calculate metrics
# n_clusters=7, linkage=complete, metric=euclidean: silhouette=0.0397, CH=74.6, DB=3.2797
# n_clusters=7, linkage=complete, metric=manhattan: silhouette=0.0824, CH=37.9, DB=3.7896
# n_clusters=7, linkage=complete, metric=cosine: silhouette=0.0144, CH=88.6, DB=4.2387
# n_clusters=7, linkage=average, metric=euclidean: Failed to calculate metrics
# n_clusters=7, linkage=average, metric=manhattan: silhouette=0.1837, CH=4.7, DB=1.3758
# n_clusters=7, linkage=average, metric=cosine: silhouette=0.0601, CH=164.2, DB=3.3510
# n_clusters=8, linkage=ward, metric=euclidean: silhouette=0.0781, CH=164.3, DB=3.1291
# n_clusters=8, linkage=ward, metric=manhattan: Failed to calculate metrics
# n_clusters=8, linkage=ward, metric=cosine: Failed to calculate metrics
# n_clusters=8, linkage=complete, metric=euclidean: silhouette=0.0221, CH=76.5, DB=3.0981
# n_clusters=8, linkage=complete, metric=manhattan: silhouette=0.0811, CH=33.4, DB=3.5955
# n_clusters=8, linkage=complete, metric=cosine: Failed to calculate metrics
# n_clusters=8, linkage=average, metric=euclidean: silhouette=0.1472, CH=4.3, DB=1.2157
# n_clusters=8, linkage=average, metric=manhattan: silhouette=0.1655, CH=4.5, DB=1.3585
# n_clusters=8, linkage=average, metric=cosine: silhouette=0.0598, CH=143.7, DB=3.2199
# n_clusters=10, linkage=ward, metric=euclidean: silhouette=0.0632, CH=145.3, DB=3.0756
# n_clusters=10, linkage=ward, metric=manhattan: Failed to calculate metrics
# n_clusters=10, linkage=ward, metric=cosine: Failed to calculate metrics
# n_clusters=10, linkage=complete, metric=euclidean: silhouette=0.0260, CH=79.6, DB=3.0586
# n_clusters=10, linkage=complete, metric=manhattan: Failed to calculate metrics
# n_clusters=10, linkage=complete, metric=cosine: silhouette=0.0243, CH=91.1, DB=4.7174
# n_clusters=10, linkage=average, metric=euclidean: silhouette=0.1305, CH=5.4, DB=1.4120
# n_clusters=10, linkage=average, metric=manhattan: silhouette=0.1503, CH=5.0, DB=1.4707
# n_clusters=10, linkage=average, metric=cosine: silhouette=0.0355, CH=119.6, DB=3.1634
# n_clusters=11, linkage=ward, metric=euclidean: silhouette=0.0641, CH=137.6, DB=3.0921
# n_clusters=11, linkage=ward, metric=manhattan: Failed to calculate metrics
# n_clusters=11, linkage=ward, metric=cosine: Failed to calculate metrics
# n_clusters=11, linkage=complete, metric=euclidean: silhouette=0.0268, CH=73.9, DB=3.2588
# n_clusters=11, linkage=complete, metric=manhattan: silhouette=0.0378, CH=33.1, DB=3.7372
# n_clusters=11, linkage=complete, metric=cosine: silhouette=0.0245, CH=86.3, DB=4.5542
# n_clusters=11, linkage=average, metric=euclidean: silhouette=0.1282, CH=5.1, DB=1.3002
# n_clusters=11, linkage=average, metric=manhattan: silhouette=0.1392, CH=4.7, DB=1.3287
# n_clusters=11, linkage=average, metric=cosine: silhouette=0.0409, CH=115.5, DB=3.1781
# n_clusters=12, linkage=ward, metric=euclidean: silhouette=0.0572, CH=130.6, DB=3.0718
# n_clusters=12, linkage=ward, metric=manhattan: Failed to calculate metrics
# n_clusters=12, linkage=ward, metric=cosine: Failed to calculate metrics
# n_clusters=12, linkage=complete, metric=euclidean: silhouette=0.0266, CH=69.6, DB=3.2476
# n_clusters=12, linkage=complete, metric=manhattan: silhouette=0.0377, CH=31.9, DB=3.6559
# n_clusters=12, linkage=complete, metric=cosine: silhouette=0.0263, CH=82.2, DB=4.4145
# n_clusters=12, linkage=average, metric=euclidean: silhouette=0.1138, CH=4.8, DB=1.2512
# n_clusters=12, linkage=average, metric=manhattan: silhouette=0.1239, CH=4.4, DB=1.2746
# n_clusters=12, linkage=average, metric=cosine: silhouette=0.0409, CH=107.5, DB=3.1001
# n_clusters=13, linkage=ward, metric=euclidean: silhouette=0.0451, CH=124.1, DB=3.1310
# n_clusters=13, linkage=ward, metric=manhattan: Failed to calculate metrics
# n_clusters=13, linkage=ward, metric=cosine: Failed to calculate metrics
# n_clusters=13, linkage=complete, metric=euclidean: silhouette=0.0240, CH=68.2, DB=3.3430
# n_clusters=13, linkage=complete, metric=manhattan: silhouette=0.0328, CH=36.1, DB=3.4703
# n_clusters=13, linkage=complete, metric=cosine: silhouette=0.0335, CH=85.9, DB=4.4199
# n_clusters=13, linkage=average, metric=euclidean: silhouette=0.1094, CH=4.7, DB=1.2869
# n_clusters=13, linkage=average, metric=manhattan: silhouette=0.1178, CH=4.4, DB=1.3149
# n_clusters=13, linkage=average, metric=cosine: silhouette=0.0346, CH=99.5, DB=3.0420
# n_clusters=14, linkage=ward, metric=euclidean: silhouette=0.0458, CH=118.5, DB=3.0723
# n_clusters=14, linkage=ward, metric=manhattan: Failed to calculate metrics
# n_clusters=14, linkage=ward, metric=cosine: Failed to calculate metrics
# n_clusters=14, linkage=complete, metric=euclidean: silhouette=0.0241, CH=63.4, DB=3.1939
# n_clusters=14, linkage=complete, metric=manhattan: silhouette=0.0296, CH=34.2, DB=3.4656
# n_clusters=14, linkage=complete, metric=cosine: silhouette=0.0339, CH=82.7, DB=4.2287
# n_clusters=14, linkage=average, metric=euclidean: silhouette=0.1076, CH=5.3, DB=1.4246
# n_clusters=14, linkage=average, metric=manhattan: silhouette=0.1168, CH=4.2, DB=1.2564
# n_clusters=14, linkage=average, metric=cosine: silhouette=0.0326, CH=92.6, DB=2.9877
# n_clusters=15, linkage=ward, metric=euclidean: silhouette=0.0377, CH=113.8, DB=2.9716
# n_clusters=15, linkage=ward, metric=manhattan: Failed to calculate metrics
# n_clusters=15, linkage=ward, metric=cosine: Failed to calculate metrics
# n_clusters=15, linkage=complete, metric=euclidean: silhouette=0.0302, CH=65.4, DB=3.3333
# n_clusters=15, linkage=complete, metric=manhattan: silhouette=0.0284, CH=33.8, DB=3.3649
# n_clusters=15, linkage=complete, metric=cosine: silhouette=0.0354, CH=79.5, DB=4.1857
# n_clusters=15, linkage=average, metric=euclidean: silhouette=0.0993, CH=5.1, DB=1.4030
# n_clusters=15, linkage=average, metric=manhattan: silhouette=0.1066, CH=4.2, DB=1.2308
# n_clusters=15, linkage=average, metric=cosine: silhouette=0.0340, CH=87.8, DB=3.0254
#
# Best Agglomerative parameters: n_clusters=5, linkage=average
# Silhouette: 0.0541, CH: 222.5, DB: 3.0067
#
# Clustering completed with 5 clusters
# Best parameters: n_clusters=5, linkage=average, metric=cosine
# Silhouette score: 0.0541
# Calinski-Harabasz score: 222.5
# Davies-Bouldin score: 3.0067

# %% [markdown]
# # Visualize Clustering Results

# %%
# Only create visualization if we have at least one cluster
n_clusters = len(set(labels))
if n_clusters > 0:
    plt.figure(figsize=(12, 10))
    scatter = plt.scatter(
        pca_result[:, 0], pca_result[:, 1], 
        c=labels, cmap='viridis', 
        alpha=0.6, s=30
    )
    plt.colorbar(scatter, label='Cluster')
    plt.title(f'High-Rated Board Game Clusters in PCA Space')
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.grid(True)
    plt.savefig(f'../plots/clusters_2d_high_rated.png')
    plt.show()
    plt.close()

# %% [markdown]
# # Analyze Cluster Profiles

# %%
# Get cluster statistics
cluster_stats = high_rated_games.groupby('HighRatingCluster').agg({
    'BGGId': 'count',
    'AvgRating': ['mean', 'median', 'min', 'max', 'std']
}).reset_index()

# Flatten multi-level columns
cluster_stats.columns = ['HighRatingCluster', 'Count', 'AvgRating_Mean', 'AvgRating_Median', 
                        'AvgRating_Min', 'AvgRating_Max', 'AvgRating_Std']

# Sort by highest average rating
cluster_stats = cluster_stats.sort_values('AvgRating_Mean', ascending=False)

print("\nCluster statistics (sorted by average rating):")
print(cluster_stats)

# Identify top mechanics, themes, and categories for each cluster
# Define feature type columns
#mechanic_cols = [col for col in all_binary_cols if 'Mech:' in col]
#theme_cols = [col for col in all_binary_cols if 'Theme:' in col]
#category_cols = [col for col in all_binary_cols if 'Cat:' in col]

# Function to get top features by prevalence
def get_top_features(df, feature_cols, n=5):
    feature_prevalence = {}
    for col in feature_cols:
        if col in df.columns:
            feature_name = col.split(':', 1)[1] if ':' in col else col
            feature_prevalence[feature_name] = df[col].mean() * 100
    
    # Sort by prevalence and get top n
    sorted_features = sorted(feature_prevalence.items(), key=lambda x: x[1], reverse=True)
    return sorted_features[:n]

# Print cluster profiles
print("\nCluster Profiles:")
for cluster_id in high_rated_games['HighRatingCluster'].unique():
    cluster_df = high_rated_games[high_rated_games['HighRatingCluster'] == cluster_id]
    
    # Get statistics
    stats = cluster_stats[cluster_stats['HighRatingCluster'] == cluster_id].iloc[0]
    
    print(f"\n==== Cluster {cluster_id} ====")
    print(f"Games: {len(cluster_df)} ({len(cluster_df) / len(high_rated_games) * 100:.1f}% of high-rated games)")
    print(f"Average Rating: {stats['AvgRating_Mean']:.2f} (min: {stats['AvgRating_Min']:.2f}, max: {stats['AvgRating_Max']:.2f})")
    
    # Top mechanics
    print("\nTop Mechanics:")
    for mechanic, prevalence in get_top_features(cluster_df, mechanics_cols):
        print(f"  {mechanic}: {prevalence:.1f}%")
    
    # Top themes
    print("\nTop Themes:")
    for theme, prevalence in get_top_features(cluster_df, themes_cols):
        print(f"  {theme}: {prevalence:.1f}%")
    
    # Top categories
    print("\nTop Categories:")
    for category, prevalence in get_top_features(cluster_df, category_cols, n=3):
        print(f"  {category}: {prevalence:.1f}%")

    # Top categories
    print("\nTop Subcategories:")
    for subcategory, prevalence in get_top_features(cluster_df, subcategories_cols, n=3):
        print(f"  {subcategory}: {prevalence:.1f}%")
    
    # Example games
    print("\nExample Games:")
    for _, game in cluster_df.sort_values('AvgRating', ascending=False).head(5).iterrows():
        print(f"  {game['Name']} ({game['YearPublished']}): {game['AvgRating']:.2f}")
# Out:
# Cluster statistics (sorted by average rating):
#    HighRatingCluster  Count  AvgRating_Mean  AvgRating_Median  AvgRating_Min  AvgRating_Max  AvgRating_Std
# 2                  2    545        7.638471          7.548240        7.00169        9.32946       0.454245
# 3                  3    753        7.628298          7.568830        7.00192        9.29208       0.426584
# 1                  1   1184        7.488867          7.408060        7.00105        9.07609       0.376041
# 0                  0    797        7.427638          7.336040        7.00025        8.75955       0.350176
# 4                  4    492        7.387085          7.295105        7.00062        8.94521       0.321274
#
# Cluster Profiles:
#
# ==== Cluster 1 ====
# Games: 1184 (31.4% of high-rated games)
# Average Rating: 7.49 (min: 7.00, max: 9.08)
#
# Top Mechanics:
#   Area Majority / Influence: 31.0%
#   Tile Placement: 29.1%
#   Set Collection: 27.4%
#   Worker Placement: 26.5%
#   Hand Management: 25.9%
#
# Top Themes:
#   Economic: 33.3%
#   City Building: 15.5%
#   Fantasy: 13.4%
#   Medieval: 13.2%
#   Science Fiction: 10.6%
#
# Top Categories:
#   Strategy: 65.5%
#   Family: 13.3%
#   Thematic: 4.5%
#
# Top Subcategories:
#   Territory Building: 11.8%
#   Card Game: 8.1%
#   Exploration: 5.2%
#
# Example Games:
#   Anachrony: Infinity Box (2020): 9.08
#   Small World Designer Edition (2015): 9.00
#   Trickerion: Collector's Edition (2019): 8.85
#   Hogs of War: The Miniatures Game (2020): 8.83
#   Clank!: Legacy – Acquisitions Incorporated (2019): 8.70
#
# ==== Cluster 0 ====
# Games: 797 (21.1% of high-rated games)
# Average Rating: 7.43 (min: 7.00, max: 8.76)
#
# Top Mechanics:
#   Hand Management: 61.7%
#   Drafting: 31.6%
#   Deck, Bag, and Pool Building: 28.2%
#   Variable Player Powers: 25.7%
#   Set Collection: 22.8%
#
# Top Themes:
#   Fantasy: 35.4%
#   Fighting: 20.2%
#   Science Fiction: 8.9%
#   Animals: 7.0%
#   Medieval: 5.9%
#
# Top Categories:
#   Strategy: 22.0%
#   Family: 19.3%
#   Thematic: 7.5%
#
# Top Subcategories:
#   Card Game: 78.3%
#   Collectible Components: 4.6%
#   Print & Play: 3.6%
#
# Example Games:
#   Aeon's End: Outcasts (2020): 8.76
#   Final Girl (2021): 8.75
#   Aeon's End: The New Age (2019): 8.68
#   Terra Mystica: Big Box (2015): 8.64
#   Clash of Cultures: Monumental Edition (2021): 8.62
#
# ==== Cluster 2 ====
# Games: 545 (14.5% of high-rated games)
# Average Rating: 7.64 (min: 7.00, max: 9.33)
#
# Top Mechanics:
#   Dice Rolling: 78.0%
#   Variable Player Powers: 68.3%
#   Cooperative Game: 49.0%
#   Modular Board: 43.9%
#   Action Points: 31.4%
#
# Top Themes:
#   Fantasy: 43.9%
#   Adventure: 41.1%
#   Fighting: 39.3%
#   Science Fiction: 29.0%
#   Horror: 14.9%
#
# Top Categories:
#   Thematic: 51.6%
#   War: 18.9%
#   Strategy: 11.9%
#
# Top Subcategories:
#   Miniatures: 58.3%
#   Exploration: 24.6%
#   Card Game: 10.3%
#
# Example Games:
#   The Fantasy Trip: Legacy Edition (2019): 9.33
#   Middara: Unintentional Malum – Act 1 Version 1.1 (2021): 9.03
#   Mage Knight: Ultimate Edition (2018): 8.95
#   Company of Heroes (2021): 8.92
#   Dungeon Universalis (2019): 8.88
#
# ==== Cluster 3 ====
# Games: 753 (20.0% of high-rated games)
# Average Rating: 7.63 (min: 7.00, max: 9.29)
#
# Top Mechanics:
#   Dice Rolling: 76.2%
#   Simulation: 63.3%
#   Hexagon Grid: 58.0%
#   Campaign / Battle Card Driven: 18.5%
#   Grid Movement: 16.6%
#
# Top Themes:
#   World War II: 40.5%
#   Modern Warfare: 9.6%
#   Aviation / Flight: 9.2%
#   Napoleonic: 8.1%
#   American Civil War: 7.0%
#
# Top Categories:
#   War: 93.9%
#   Thematic: 5.2%
#   Strategy: 2.5%
#
# Top Subcategories:
#   Card Game: 4.2%
#   Miniatures: 3.9%
#   Print & Play: 2.3%
#
# Example Games:
#   Wings of the Motherland (2019): 9.29
#   1985: Under an Iron Sky (2018): 9.05
#   World At War 85: Storming the Gap (2019): 8.83
#   Roads to Gettysburg II: Lee Strikes North (2018): 8.81
#   Last Chance for Victory: The Battle of Gettysburg (2014): 8.79
#
# ==== Cluster 4 ====
# Games: 492 (13.0% of high-rated games)
# Average Rating: 7.39 (min: 7.00, max: 8.95)
#
# Top Mechanics:
#   Deduction: 28.9%
#   Cooperative Game: 27.0%
#   Dice Rolling: 26.8%
#   Team-Based Game: 16.1%
#   Solo / Solitaire Game: 14.6%
#
# Top Themes:
#   Science Fiction: 13.4%
#   Murder/Mystery: 9.1%
#   Humor: 7.3%
#   Animals: 5.7%
#   Horror: 5.7%
#
# Top Categories:
#   Family: 15.9%
#   Party: 14.4%
#   Thematic: 12.6%
#
# Top Subcategories:
#   Card Game: 13.0%
#   Puzzle: 10.6%
#   Exploration: 4.5%
#
# Example Games:
#   Star Trek: Alliance – Dominion War Campaign (2021): 8.95
#   Anno Domini 1666 (2019): 8.83
#   Doctor Who: Solitaire Story Game (Second Edition) (2017): 8.62
#   Red White & Blue Racin': Stock Car Action Game (2012): 8.54
#   Sherlock Holmes Consulting Detective: The Baker Street Irregulars (2020): 8.52

# %% [markdown]
# # Decision Tree Analysis of High-Rated Clusters

# %%
# For each cluster, build a decision tree to distinguish it from other clusters
for cluster_id in sorted(high_rated_games['HighRatingCluster'].unique()):
    # Create binary target: 1 for this cluster, 0 for other clusters
    y = (high_rated_games['HighRatingCluster'] == cluster_id).astype(int)
    X = high_rated_games[all_binary_cols]
    
    # Train a decision tree
    dt = DecisionTreeClassifier(max_depth=3, min_samples_leaf=10, random_state=42)
    dt.fit(X, y)
    
    # Get feature importances
    importances = pd.DataFrame({
        'Feature': all_binary_cols,
        'Importance': dt.feature_importances_
    }).sort_values('Importance', ascending=False)
    
    # Print top features
    print(f"\nTop features for identifying Cluster {cluster_id}:")
    for _, row in importances[importances['Importance'] > 0].head(10).iterrows():
        print(f"  {row['Feature']}: {row['Importance']:.4f}")
    
    # Visualize the decision tree
    plt.figure(figsize=(20, 10))
    plot_tree(
        dt, 
        feature_names=all_binary_cols, 
        class_names=[f'Other Clusters', f'Cluster {cluster_id}'],
        filled=True, 
        rounded=True,
        fontsize=10
    )
    plt.title(f'Decision Tree for High-Rated Cluster {cluster_id}')
    plt.tight_layout()
    plt.savefig(f'../plots/high_rated_cluster_{cluster_id}_decision_tree.png')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # For each cluster, build a decision tree to distinguish it from other clusters
# ----> 2 for cluster_id in sorted(high_rated_games['HighRatingCluster'].unique()):
#       3     # Create binary target: 1 for this cluster, 0 for other clusters
#       4     y = (high_rated_games['HighRatingCluster'] == cluster_id).astype(int)
#       5     X = high_rated_games[all_binary_cols]
#
# NameError: name 'high_rated_games' is not defined

# %% [markdown]
# # Save Results

# %%
# Save high-rated games with cluster assignments
high_rated_games.to_csv('../frames/high_rated_games_with_clusters.csv', index=False)

# Create a cluster assignments DataFrame for integration with the main dataset
high_rating_clusters = pd.DataFrame({
    'BGGId': high_rated_games['BGGId'],
    'HighRatingCluster': high_rated_games['HighRatingCluster']
})

# Save cluster assignments
high_rating_clusters.to_csv('../frames/high_rating_clustering_assignments.csv', index=False)

# Save cluster statistics
cluster_stats.to_csv('../frames/high_rating_cluster_statistics.csv', index=False)

print(f"Saved clustering results for {len(high_rated_games)} high-rated games")
# Out:
# Saved clustering results for 3771 high-rated games
